# %%
import numpy as np
import numpy.random as rand
from scipy.stats import normaltest
import matplotlib.pyplot as plt

# %%
x = rand.normal(3,4,500)
z = rand.normal(1,2,500)

# %%
plt.hist(x)
# Out:
# (array([  8.,  22.,  43.,  68., 117., 122.,  63.,  42.,  10.,   5.]),
#  array([-7.70069844, -5.4882454 , -3.27579235, -1.0633393 ,  1.14911375,
#          3.3615668 ,  5.57401984,  7.78647289,  9.99892594, 12.21137899,
#         14.42383204]),
#  <BarContainer object of 10 artists>)

# %%
y = 3+4*rand.uniform(0,1,size=500)
y = rand.uniform(3,7,size=500)
w = rand.uniform(2.1,5.4,size=500)

# %%
a = x+z
b = y+w
c = x+y

# %%
normaltest(x)
# Out:
# NormaltestResult(statistic=np.float64(0.966009683570969), pvalue=np.float64(0.616926836338915))

# %%
normaltest(y)
# Out:
# NormaltestResult(statistic=np.float64(413.32657049582195), pvalue=np.float64(1.7671589103020962e-90))

# %%
normaltest(a)
# Out:
# NormaltestResult(statistic=np.float64(1.6952697931293095), pvalue=np.float64(0.42842700883408336))

# %%
normaltest(b)
# Out:
# NormaltestResult(statistic=np.float64(13.05225402902336), pvalue=np.float64(0.001464667514966911))

# %%
normaltest(c)
# Out:
# NormaltestResult(statistic=np.float64(1.3819585767757352), pvalue=np.float64(0.5010851218746636))

# %%
from scipy.stats import pearsonr

# %%
pearsonr(a,x)
# Out:
# PearsonRResult(statistic=np.float64(0.8909726699546675), pvalue=np.float64(6.981589280059154e-173))

# %%
pearsonr(z,x)
# Out:
# PearsonRResult(statistic=np.float64(0.025980333178040292), pvalue=np.float64(0.5621967171600661))

# %%
pearsonr(a,c)
# Out:
# PearsonRResult(statistic=np.float64(0.849887461706732), pvalue=np.float64(1.1760336181188264e-140))

# %%
# Avalie a normalisdade

# %% [markdown]
# # Normalidade e correlação
#
# Avalie a normalidade dos dados e a possibilidade de correlação entre as variáveis do conjunto de dados de erupções do gêiser em:
# [https://www.kaggle.com/datasets/emmanueldjegou/old-faithful-dataset/data]
#
# Verifique se é possivel obter normalidade de alguma das variáveis separando-as por algum valor. Mostre.

# %%
import pandas as pd

# %%
url = 'https://storage.googleapis.com/kagglesdsdata/datasets/2837001/4892396/OldFaithful.txt?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20251127%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20251127T233621Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...'
T = pd.read_csv(url,delimiter=r'\s+')

# %%
T.head()
# Out:
#    D   Y    X
# 0  1  78  4.4
# 1  1  74  3.9
# 2  1  68  4.0
# 3  1  76  4.0
# 4  1  80  3.5

# %%
T.hist(bins=20)
# Out:
# array([[<Axes: title={'center': 'D'}>, <Axes: title={'center': 'Y'}>],
#        [<Axes: title={'center': 'X'}>, <Axes: >]], dtype=object)

# %%
normaltest(T['X'])
# Out:
# NormaltestResult(statistic=np.float64(34.25516295029311), pvalue=np.float64(3.644063003147748e-08))

# %%
normaltest(T.loc[T['Y']>=62,'Y'])
# Out:
# NormaltestResult(statistic=np.float64(1.3670419370543774), pvalue=np.float64(0.5048363465187116))

# %%
normaltest(T.loc[T['Y']<62,'Y'])
# Out:
# NormaltestResult(statistic=np.float64(0.46406058967672925), pvalue=np.float64(0.7929221014959165))

# %%
normaltest(T.loc[T['X']<2.5,'X'])
# Out:
# NormaltestResult(statistic=np.float64(8.855302277426851), pvalue=np.float64(0.011942508049089251))

# %%
normaltest(T.loc[T['X']>=2.5,'X'])
# Out:
# NormaltestResult(statistic=np.float64(7.274572608267459), pvalue=np.float64(0.026323681593522066))

# %%
pearsonr(T['X'],T['Y'])
# Out:
# PearsonRResult(statistic=np.float64(0.8584272968859495), pvalue=np.float64(3.2489131712044824e-32))

# %% [markdown]
# # Exercício
#
# Considerando um intervalo com distribuição normal na variável `X`, calcule o intervalo de confiança de 95%.
